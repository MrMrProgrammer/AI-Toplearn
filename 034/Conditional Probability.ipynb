# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sb

random.seed(0)

# %% [markdown]
# مقداردهی اولیه برای تعداد کل و تعداد سفارش ها بر اساس سن

# %%
totals = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
purchases = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
totalPurchases = 0

# %% [markdown]
# .در اینجا یک سن انتخاب می شود و تقسیم بر صد می شود تا یک عدد در بازه [0 - 1] ایجاد شود
#
# .سپس اگر عدد رندوم ایجاد شده از به درصد تبدیل شده ی انتخاب قبلی کوچک تر بود به آن اضافه می شود

# %%
for _ in range(100000):
    age = random.choice([20,30,40,50,60,70])
    purchaseProbability = float(age) / 100.0
    totals[age] += 1

    if random.random() < purchaseProbability:
        totalPurchases += 1
        purchases[age] += 1

# %%
print(f'totals : {totals}')

print(f'purchases : {purchases}')

print(f'totalPurchases : {totalPurchases}')
# Out:
# totals : {20: 16576, 30: 16619, 40: 16632, 50: 16805, 60: 16664, 70: 16704}
# purchases : {20: 3392, 30: 4974, 40: 6670, 50: 8319, 60: 9944, 70: 11713}
# totalPurchases : 45012

# %% [markdown]
# باعث می شود تا اعداد یکسان تولید شود seed() استفاده از دستور

# %%
random.seed(10)
print(random.random())

random.seed(10)
print(random.random())
# Out:
# 0.771320643266746
# 0.771320643266746

# %% [markdown]
# P => probability
#
# E => purchases
#
# F => people
#
# P ( E | F )

# %%
PEF = float(purchases[20]) / float(45012.0)
PEF
# Out:
# 0.07535768239580556

# %%
PF = float(totals[30]) / 100000.0
PF
# Out:
# 0.16619

# %%
PE = float(totalPurchases) / 100000.0
PE
# Out:
# 0.45012

# %% [markdown]
# P(E, F)

# %%
print('30, purchases', str(float(purchases[30] / 100000.0)))
# Out:
# 30, purchases 0.04974

# %% [markdown]
# رسم نمودار تعداد خرید براساس سن

# %%
x = [20,30,40,50,60,70]
y = []

with plt.xkcd():

    for i in x:
        y.append(purchases[i])

    print(purchases)

    sb.set()

    plt.bar(x, y)
    plt.show()
# Out:
# {20: 3392, 30: 4974, 40: 6670, 50: 8319, 60: 9944, 70: 11713}
