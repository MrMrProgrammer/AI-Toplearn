# %%
import pandas as pd
import numpy as np

# %%
r_cols = ['user_id', 'movie_id', 'rating']
rating = pd.read_csv('../Data/movies data/movies_data.txt', sep='\t', names=r_cols, usecols=range(3))

m_cols = ['movie_id', 'title']
movies = pd.read_csv('../Data/movies data/movies_item.txt', sep='|', names=m_cols, usecols=range(2))

ratings = pd.merge(movies, rating)

movieRating = ratings.pivot_table(index='user_id', columns='title', values='rating')
movieRating.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
starWarsRating = movieRating['Star Wars (1977)']

similarMovies = movieRating.corrwith(starWarsRating)
similarMovies = similarMovies.dropna()

similarMovies = similarMovies.sort_values(ascending=False)

df = pd.DataFrame(similarMovies)
df.head()
# Out:
#                        0
# title
# Hollow Reed (1996)   1.0
# Commandments (1997)  1.0
# Cosi (1996)          1.0
# No Escape (1994)     1.0
# Stripes (1981)       1.0

# %%
movieStats = ratings.groupby('title').agg({'rating': [np.size, np.mean]})
movieStats.head()
# Out:
#                           rating
#                             size      mean
# title
# 'Til There Was You (1997)      9  2.333333
# 1-900 (1994)                   5  2.600000
# 101 Dalmatians (1996)        109  2.908257
# 12 Angry Men (1957)          125  4.344000
# 187 (1997)                    41  3.024390

# %%
popularMovies = movieStats['rating']['size'] >= 100
movieStats[popularMovies].sort_values([('rating', 'mean')], ascending=False)[:15]
# Out:
#                                        rating
#                                          size      mean
# title
# Close Shave, A (1995)                     112  4.491071
# Schindler's List (1993)                   298  4.466443
# Wrong Trousers, The (1993)                118  4.466102
# Casablanca (1942)                         243  4.456790
# Shawshank Redemption, The (1994)          283  4.445230
# Rear Window (1954)                        209  4.387560
# Usual Suspects, The (1995)                267  4.385768
# Star Wars (1977)                          584  4.359589
# 12 Angry Men (1957)                       125  4.344000
# Citizen Kane (1941)                       198  4.292929
# To Kill a Mockingbird (1962)              219  4.292237
# One Flew Over the Cuckoo's Nest (1975)    264  4.291667
# Silence of the Lambs, The (1991)          390  4.289744
# North by Northwest (1959)                 179  4.284916
# Godfather, The (1972)                     413  4.283293

# %%
df = movieStats[popularMovies].join(pd.DataFrame(similarMovies, columns=['similarity']))
df.head()
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df = movieStats[popularMovies].join(pd.DataFrame(similarMovies, columns=['similarity']))
#       2 df.head()
#
# File m:\Programming\Learning\AI\Toplearn\AI - Toplearn\AI-venv\Lib\site-packages\pandas\core\frame.py:10730, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10720     if how == "cross":
#   10721         return merge(
#   10722             self,
#   10723             other,
#    (...)
#   10728             validate=validate,
#   10729         )
# > 10730     return merge(
#   10731         self,
#   10732         other,
#   10733         left_on=on,
#   10734         how=how,
#   10735         left_index=on is None,
#   10736         right_index=True,
#   10737         suffixes=(lsuffix, rsuffix),
#   10738         sort=sort,
# ...

# %%
import pandas as pd

# ایجاد داده‌ها
data_rating = {'rating': [''], 'size': [''], 'mean': ['']}
data_size_mean = {'title': [''], 'size': ['Medium'], 'mean': [4.5]}
data_title = {'title': ['Book']}

# ایجاد دیتافریم‌ها
df_rating = pd.DataFrame(data_rating)
df_size_mean = pd.DataFrame(data_size_mean)
df_title = pd.DataFrame(data_title)

# افزودن دیتافریم‌ها
df = pd.concat([df_rating, df_size_mean, df_title], axis=0, ignore_index=True)

# تنظیم هدرهای ردیفها
df.index = ['rating', '', 'title']

print(df)
# Out:
#        rating    size mean title
# rating                       NaN
#           NaN  Medium  4.5
# title     NaN     NaN  NaN  Book
