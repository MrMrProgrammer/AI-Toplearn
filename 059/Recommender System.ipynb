# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

# %%
r_cols = ['user_id', 'movie_id', 'rating']
rating = pd.read_csv('../Data/movies data/movies_data.txt', sep='\t', names=r_cols, usecols=range(3))

m_cols = ['movie_id', 'title']
movies = pd.read_csv('../Data/movies data/movies_item.txt', sep='|', names=m_cols, usecols=range(2))

ratings = pd.merge(movies, rating)

movieRating = ratings.pivot_table(index='user_id', columns='title', values='rating')
movieRating.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %% [markdown]
# Calculating the correlation coefficient between movies

# %%
corrMatrix = movieRating.corr()
corrMatrix.head(10)
# Out:
# title                                        'Til There Was You (1997)  \
# title
# 'Til There Was You (1997)                                     1.000000
# 1-900 (1994)                                                       NaN
# 101 Dalmatians (1996)                                        -1.000000
# 12 Angry Men (1957)                                          -0.500000
# 187 (1997)                                                   -0.500000
# 2 Days in the Valley (1996)                                   0.522233
# 20,000 Leagues Under the Sea (1954)                                NaN
# 2001: A Space Odyssey (1968)                                 -0.426401
# 3 Ninjas: High Noon At Mega Mountain (1998)                        NaN
# 39 Steps, The (1935)                                               NaN
#
# title                                        1-900 (1994)  \
# title
# 'Til There Was You (1997)                             NaN
# ...

# %%
corrMatrix = movieRating.corr(method="pearson", min_periods=100)
corrMatrix.head(10)
# Out:
# title                                        'Til There Was You (1997)  \
# title
# 'Til There Was You (1997)                                          NaN
# 1-900 (1994)                                                       NaN
# 101 Dalmatians (1996)                                              NaN
# 12 Angry Men (1957)                                                NaN
# 187 (1997)                                                         NaN
# 2 Days in the Valley (1996)                                        NaN
# 20,000 Leagues Under the Sea (1954)                                NaN
# 2001: A Space Odyssey (1968)                                       NaN
# 3 Ninjas: High Noon At Mega Mountain (1998)                        NaN
# 39 Steps, The (1935)                                               NaN
#
# title                                        1-900 (1994)  \
# title
# 'Til There Was You (1997)                             NaN
# ...

# %%
myRatings = movieRating.loc[0].dropna()
myRatings
# Out:
# title
# Empire Strikes Back, The (1980)    5.0
# Gone with the Wind (1939)          1.0
# Star Wars (1977)                   5.0
# Name: 0, dtype: float64
